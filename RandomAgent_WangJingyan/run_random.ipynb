# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
import itertools

# %matplotlib inline
#import environment
sys.path.append(r'../virl')
import virl

#import sklearn

# %% [markdown]
# ## Training Phase

# %%
env = virl.Epidemic(stochastic=False, noisy=False)

states = []
rewards = []
done = False

s = env.reset()
states.append(s)
while not done:
    #take random action
    s, r, done, i = env.step(action=np.random.choice(env.action_space.n))
    states.append(s)
    rewards.append(r)

# %%
states[:10]
# Out:
# [array([5.9996e+08, 2.0000e+04, 0.0000e+00, 2.0000e+04]),
#  array([5.99847798e+08, 8.92380090e+04, 1.95993039e+04, 4.33649465e+04]),
#  array([5.99845260e+08, 3.62485170e+04, 3.93495657e+04, 7.91416051e+04]),
#  array([5.99764311e+08, 6.95021210e+04, 5.19713975e+04, 1.14214987e+05]),
#  array([5.99762336e+08, 2.82316210e+04, 5.91640645e+04, 1.50268791e+05]),
#  array([5.99722400e+08, 3.75748360e+04, 5.95878894e+04, 1.80437334e+05]),
#  array([5.99721332e+08, 1.52627767e+04, 5.64505999e+04, 2.06954874e+05]),
#  array([5.99699743e+08, 2.03126329e+04, 5.12211162e+04, 2.28722803e+05]),
#  array([5.99671014e+08, 2.70319183e+04, 4.95949534e+04, 2.52358787e+05]),
#  array([5.99632785e+08, 3.59714719e+04, 5.15734901e+04, 2.79669801e+05])]

# %%
rewards[:10]
# Out:
# [-4.8776647817295665e-05,
#  -0.0314875418133799,
#  -0.007700865247627066,
#  -0.03149746800963266,
#  -0.012171310569434777,
#  -0.03148219244939436,
#  -0.012154194252130376,
#  -0.012156456825665815,
#  -0.01216320005652553,
#  -0.012175070958121174]

# %% [markdown]
# ## Evaluation phase

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 8))
labels = ['s[0]: susceptibles', 's[1]: infectious', 's[2]: quarantined', 's[3]: recovereds']
states = np.array(states)
for i in range(4):
    axes[0].plot(states[:,i], label=labels[i]);
axes[0].set_xlabel('weeks since start of epidemic')
axes[0].set_ylabel('State s(t)')
axes[0].legend()
axes[1].plot(rewards);
axes[1].set_title('Reward')
axes[1].set_xlabel('weeks since start of epidemic')
axes[1].set_ylabel('reward r(t)')

print('total reward', np.sum(rewards))
# Out:
# total reward -1.7318963754260805
